# %%
import nltk
import numpy as np
from nltk.corpus import gutenberg
from string import punctuation
import re
from keras.preprocessing import text
import pandas as pd

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    doc = doc.lower().strip()
    tokens = wpt.tokenize(doc)
    filtered_tokens = [token for token in tokens if token not in stop_words]
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
alice = gutenberg.sents('carroll-alice.txt') 
remove_terms = punctuation + '0123456789'
alice = [[word.lower() for word in sent if word not in remove_terms] for sent in alice]
alice = [' '.join(tok_sent) for tok_sent in alice]
alice = list(map(normalize_corpus,alice))
alice = [str(sent) for sent in alice if len(str(sent).split()) > 2]

# %%
tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(alice)
word2id = tokenizer.word_index
word2id['PAD'] = 0
id2word = {v:k for k, v in word2id.items()}
wids = [[word2id[w] for w in text.text_to_word_sequence(doc)] for doc in alice]
vocab_size = len(word2id)
embed_size = 100
window_size = 2

# %%
from keras.preprocessing.sequence import skipgrams
skip_grams = [skipgrams(wid, vocabulary_size=vocab_size, window_size=10) for wid in wids]
pairs, labels = skip_grams[0][0], skip_grams[0][1]

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F

class skipgram(nn.Module):
    
  def __init__(self, vocab_size, embedding_dim=100):
    super(skipgram, self).__init__()
    
    self.u_embeddings = nn.Embedding(vocab_size, embedding_dim, sparse=True)   
    self.v_embeddings = nn.Embedding(vocab_size, embedding_dim, sparse=True) 
    self.lin = nn.Linear(embedding_dim,1)
 
  def forward(self, u_pos, v_pos ):

    embed_u = self.u_embeddings(torch.Tensor([u_pos]).long())
    embed_v = self.v_embeddings(torch.Tensor([v_pos]).long())
    score  = torch.mul(embed_u, embed_v)
    score = self.lin(score)
    print(score)
    target = F.sigmoid(score).squeeze()
    print(target)
    return target

model = skipgram(vocab_size)
loss_function = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# %%
for epoch in range(1, 100):
    tloss = 0
    for i, elem in enumerate(skip_grams):
        pair_first_elem = np.array(list(zip(*elem[0]))[0], dtype='int32')
        pair_second_elem = np.array(list(zip(*elem[0]))[1], dtype='int32')
        labels = np.array(elem[1], dtype='int32')
        optimizer.zero_grad()
        for v,u,l in zip(pair_first_elem,pair_second_elem,labels):            
            p = model(v, u)
            loss = loss_function(p,torch.Tensor([l]))
            loss += loss.data
        loss.backward()
        tloss+=loss
        optimizer.step()
    print('Epoch:', epoch, '\tLoss:', tloss)
# Out:
# tensor([[0.8911]], grad_fn=<AddmmBackward>)
# tensor(0.7091, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0023]], grad_fn=<AddmmBackward>)
# tensor(0.4994, grad_fn=<SqueezeBackward0>)
# tensor([[-1.3037]], grad_fn=<AddmmBackward>)
# tensor(0.2135, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0292]], grad_fn=<AddmmBackward>)
# tensor(0.4927, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4561]], grad_fn=<AddmmBackward>)
# tensor(0.3879, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6752]], grad_fn=<AddmmBackward>)
# tensor(0.3373, grad_fn=<SqueezeBackward0>)
# tensor([[0.6819]], grad_fn=<AddmmBackward>)
# tensor(0.6642, grad_fn=<SqueezeBackward0>)
# tensor([[0.0179]], grad_fn=<AddmmBackward>)
# tensor(0.5045, grad_fn=<SqueezeBackward0>)
# tensor([[0.6263]], grad_fn=<AddmmBackward>)
# tensor(0.6516, grad_fn=<SqueezeBackward0>)
# tensor([[0.9062]], grad_fn=<AddmmBackward>)
# tensor(0.7122, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1125]], grad_fn=<AddmmBackward>)
# tensor(0.4719, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0032]], grad_fn=<AddmmBackward>)
# tensor(0.4992, grad_fn=<SqueezeBackward0>)
# tensor([[0.2875]], grad_fn=<AddmmBackward>)
# tensor(0.5714, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3660]], grad_fn=<AddmmBackward>)
# tensor(0.4095, grad_fn=<SqueezeBackward0>)
# tensor([[0.3717]], grad_fn=<AddmmBackward>)
# tensor(0.5919, grad_fn=<SqueezeBackward0>)
# tensor([[0.1121]], grad_fn=<AddmmBackward>)
# tensor(0.5280, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7417]], grad_fn=<AddmmBackward>)
# tensor(0.3226, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3003]], grad_fn=<AddmmBackward>)
# tensor(0.4255, grad_fn=<SqueezeBackward0>)
# tensor([[0.2608]], grad_fn=<AddmmBackward>)
# tensor(0.5648, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3259]], grad_fn=<AddmmBackward>)
# tensor(0.4192, grad_fn=<SqueezeBackward0>)
# tensor([[0.2718]], grad_fn=<AddmmBackward>)
# tensor(0.5675, grad_fn=<SqueezeBackward0>)
# tensor([[0.0193]], grad_fn=<AddmmBackward>)
# tensor(0.5048, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3109]], grad_fn=<AddmmBackward>)
# tensor(0.4229, grad_fn=<SqueezeBackward0>)
# tensor([[0.0828]], grad_fn=<AddmmBackward>)
# tensor(0.5207, grad_fn=<SqueezeBackward0>)
# tensor([[0.8286]], grad_fn=<AddmmBackward>)
# tensor(0.6961, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1403]], grad_fn=<AddmmBackward>)
# tensor(0.4650, grad_fn=<SqueezeBackward0>)
# tensor([[0.8914]], grad_fn=<AddmmBackward>)
# tensor(0.7092, grad_fn=<SqueezeBackward0>)
# tensor([[0.2200]], grad_fn=<AddmmBackward>)
# tensor(0.5548, grad_fn=<SqueezeBackward0>)
# tensor([[1.3167]], grad_fn=<AddmmBackward>)
# tensor(0.7886, grad_fn=<SqueezeBackward0>)
# tensor([[0.5564]], grad_fn=<AddmmBackward>)
# tensor(0.6356, grad_fn=<SqueezeBackward0>)
# tensor([[1.3613]], grad_fn=<AddmmBackward>)
# tensor(0.7960, grad_fn=<SqueezeBackward0>)
# tensor([[0.5381]], grad_fn=<AddmmBackward>)
# tensor(0.6314, grad_fn=<SqueezeBackward0>)
# tensor([[-1.1496]], grad_fn=<AddmmBackward>)
# tensor(0.2406, grad_fn=<SqueezeBackward0>)
# tensor([[0.7873]], grad_fn=<AddmmBackward>)
# tensor(0.6872, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1712]], grad_fn=<AddmmBackward>)
# tensor(0.4573, grad_fn=<SqueezeBackward0>)
# tensor([[0.4864]], grad_fn=<AddmmBackward>)
# tensor(0.6193, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0563]], grad_fn=<AddmmBackward>)
# tensor(0.4859, grad_fn=<SqueezeBackward0>)
# tensor([[1.0149]], grad_fn=<AddmmBackward>)
# tensor(0.7340, grad_fn=<SqueezeBackward0>)
# tensor([[0.0428]], grad_fn=<AddmmBackward>)
# tensor(0.5107, grad_fn=<SqueezeBackward0>)
# tensor([[0.4432]], grad_fn=<AddmmBackward>)
# tensor(0.6090, grad_fn=<SqueezeBackward0>)
# tensor([[0.2786]], grad_fn=<AddmmBackward>)
# tensor(0.5692, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2908]], grad_fn=<AddmmBackward>)
# tensor(0.4278, grad_fn=<SqueezeBackward0>)
# tensor([[0.4949]], grad_fn=<AddmmBackward>)
# tensor(0.6213, grad_fn=<SqueezeBackward0>)
# tensor([[0.8171]], grad_fn=<AddmmBackward>)
# tensor(0.6936, grad_fn=<SqueezeBackward0>)
# tensor([[0.3718]], grad_fn=<AddmmBackward>)
# tensor(0.5919, grad_fn=<SqueezeBackward0>)
# tensor([[0.2937]], grad_fn=<AddmmBackward>)
# tensor(0.5729, grad_fn=<SqueezeBackward0>)
# tensor([[0.4610]], grad_fn=<AddmmBackward>)
# tensor(0.6133, grad_fn=<SqueezeBackward0>)
# tensor([[0.2786]], grad_fn=<AddmmBackward>)
# tensor(0.5692, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8174]], grad_fn=<AddmmBackward>)
# tensor(0.3063, grad_fn=<SqueezeBackward0>)
# tensor([[0.4431]], grad_fn=<AddmmBackward>)
# tensor(0.6090, grad_fn=<SqueezeBackward0>)
# tensor([[0.9713]], grad_fn=<AddmmBackward>)
# tensor(0.7254, grad_fn=<SqueezeBackward0>)
# tensor([[1.3026]], grad_fn=<AddmmBackward>)
# tensor(0.7863, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0288]], grad_fn=<AddmmBackward>)
# tensor(0.4928, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3935]], grad_fn=<AddmmBackward>)
# tensor(0.4029, grad_fn=<SqueezeBackward0>)
# tensor([[1.0091]], grad_fn=<AddmmBackward>)
# tensor(0.7328, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9297]], grad_fn=<AddmmBackward>)
# tensor(0.2830, grad_fn=<SqueezeBackward0>)
# tensor([[0.6555]], grad_fn=<AddmmBackward>)
# tensor(0.6582, grad_fn=<SqueezeBackward0>)
# tensor([[0.6406]], grad_fn=<AddmmBackward>)
# tensor(0.6549, grad_fn=<SqueezeBackward0>)
# tensor([[0.8002]], grad_fn=<AddmmBackward>)
# tensor(0.6900, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8280]], grad_fn=<AddmmBackward>)
# tensor(0.3041, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3539]], grad_fn=<AddmmBackward>)
# tensor(0.4124, grad_fn=<SqueezeBackward0>)
# tensor([[0.2803]], grad_fn=<AddmmBackward>)
# tensor(0.5696, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0497]], grad_fn=<AddmmBackward>)
# tensor(0.2593, grad_fn=<SqueezeBackward0>)
# tensor([[0.3798]], grad_fn=<AddmmBackward>)
# tensor(0.5938, grad_fn=<SqueezeBackward0>)
# tensor([[1.3468]], grad_fn=<AddmmBackward>)
# tensor(0.7936, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3046]], grad_fn=<AddmmBackward>)
# tensor(0.4244, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0821]], grad_fn=<AddmmBackward>)
# tensor(0.2531, grad_fn=<SqueezeBackward0>)
# tensor([[0.2055]], grad_fn=<AddmmBackward>)
# tensor(0.5512, grad_fn=<SqueezeBackward0>)
# tensor([[0.0537]], grad_fn=<AddmmBackward>)
# tensor(0.5134, grad_fn=<SqueezeBackward0>)
# tensor([[0.4435]], grad_fn=<AddmmBackward>)
# tensor(0.6091, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3539]], grad_fn=<AddmmBackward>)
# tensor(0.4124, grad_fn=<SqueezeBackward0>)
# tensor([[0.6280]], grad_fn=<AddmmBackward>)
# tensor(0.6520, grad_fn=<SqueezeBackward0>)
# tensor([[0.4780]], grad_fn=<AddmmBackward>)
# tensor(0.6173, grad_fn=<SqueezeBackward0>)
# tensor([[0.0268]], grad_fn=<AddmmBackward>)
# tensor(0.5067, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0590]], grad_fn=<AddmmBackward>)
# tensor(0.4852, grad_fn=<SqueezeBackward0>)
# tensor([[0.6195]], grad_fn=<AddmmBackward>)
# tensor(0.6501, grad_fn=<SqueezeBackward0>)
# tensor([[1.1782]], grad_fn=<AddmmBackward>)
# tensor(0.7646, grad_fn=<SqueezeBackward0>)
# tensor([[0.7275]], grad_fn=<AddmmBackward>)
# tensor(0.6743, grad_fn=<SqueezeBackward0>)
# tensor([[0.2057]], grad_fn=<AddmmBackward>)
# tensor(0.5512, grad_fn=<SqueezeBackward0>)
# tensor([[0.6910]], grad_fn=<AddmmBackward>)
# tensor(0.6662, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0976]], grad_fn=<AddmmBackward>)
# tensor(0.4756, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1411]], grad_fn=<AddmmBackward>)
# tensor(0.4648, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2012]], grad_fn=<AddmmBackward>)
# tensor(0.4499, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9055]], grad_fn=<AddmmBackward>)
# tensor(0.2879, grad_fn=<SqueezeBackward0>)
# tensor([[0.0146]], grad_fn=<AddmmBackward>)
# tensor(0.5036, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1963]], grad_fn=<AddmmBackward>)
# tensor(0.4511, grad_fn=<SqueezeBackward0>)
# tensor([[0.1079]], grad_fn=<AddmmBackward>)
# tensor(0.5269, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0592]], grad_fn=<AddmmBackward>)
# tensor(0.4852, grad_fn=<SqueezeBackward0>)
# tensor([[1.1063]], grad_fn=<AddmmBackward>)
# tensor(0.7514, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2030]], grad_fn=<AddmmBackward>)
# tensor(0.4494, grad_fn=<SqueezeBackward0>)
# tensor([[0.3577]], grad_fn=<AddmmBackward>)
# tensor(0.5885, grad_fn=<SqueezeBackward0>)
# tensor([[0.8710]], grad_fn=<AddmmBackward>)
# tensor(0.7050, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1510]], grad_fn=<AddmmBackward>)
# tensor(0.4623, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4782]], grad_fn=<AddmmBackward>)
# tensor(0.3827, grad_fn=<SqueezeBackward0>)
# tensor([[1.0442]], grad_fn=<AddmmBackward>)
# tensor(0.7397, grad_fn=<SqueezeBackward0>)
# tensor([[0.5877]], grad_fn=<AddmmBackward>)
# tensor(0.6428, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2073]], grad_fn=<AddmmBackward>)
# tensor(0.4484, grad_fn=<SqueezeBackward0>)
# tensor([[0.8589]], grad_fn=<AddmmBackward>)
# tensor(0.7024, grad_fn=<SqueezeBackward0>)
# tensor([[0.0489]], grad_fn=<AddmmBackward>)
# tensor(0.5122, grad_fn=<SqueezeBackward0>)
# tensor([[0.2762]], grad_fn=<AddmmBackward>)
# tensor(0.5686, grad_fn=<SqueezeBackward0>)
# tensor([[0.3140]], grad_fn=<AddmmBackward>)
# tensor(0.5779, grad_fn=<SqueezeBackward0>)
# tensor([[0.2937]], grad_fn=<AddmmBackward>)
# tensor(0.5729, grad_fn=<SqueezeBackward0>)
# tensor([[0.3366]], grad_fn=<AddmmBackward>)
# tensor(0.5834, grad_fn=<SqueezeBackward0>)
# tensor([[0.0608]], grad_fn=<AddmmBackward>)
# tensor(0.5152, grad_fn=<SqueezeBackward0>)
# tensor([[0.4867]], grad_fn=<AddmmBackward>)
# tensor(0.6193, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4212]], grad_fn=<AddmmBackward>)
# tensor(0.3962, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4513]], grad_fn=<AddmmBackward>)
# tensor(0.3891, grad_fn=<SqueezeBackward0>)
# tensor([[0.6962]], grad_fn=<AddmmBackward>)
# tensor(0.6673, grad_fn=<SqueezeBackward0>)
# tensor([[0.0423]], grad_fn=<AddmmBackward>)
# tensor(0.5106, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9006]], grad_fn=<AddmmBackward>)
# tensor(0.2889, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1782]], grad_fn=<AddmmBackward>)
# tensor(0.4556, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8705]], grad_fn=<AddmmBackward>)
# tensor(0.2952, grad_fn=<SqueezeBackward0>)
# tensor([[0.1744]], grad_fn=<AddmmBackward>)
# tensor(0.5435, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5883]], grad_fn=<AddmmBackward>)
# tensor(0.3570, grad_fn=<SqueezeBackward0>)
# tensor([[0.7222]], grad_fn=<AddmmBackward>)
# tensor(0.6731, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7003]], grad_fn=<AddmmBackward>)
# tensor(0.3318, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2519]], grad_fn=<AddmmBackward>)
# tensor(0.4373, grad_fn=<SqueezeBackward0>)
# tensor([[0.6885]], grad_fn=<AddmmBackward>)
# tensor(0.6656, grad_fn=<SqueezeBackward0>)
# tensor([[1.0468]], grad_fn=<AddmmBackward>)
# tensor(0.7402, grad_fn=<SqueezeBackward0>)
# tensor([[0.9525]], grad_fn=<AddmmBackward>)
# tensor(0.7216, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1395]], grad_fn=<AddmmBackward>)
# tensor(0.4652, grad_fn=<SqueezeBackward0>)
# tensor([[0.6585]], grad_fn=<AddmmBackward>)
# tensor(0.6589, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2038]], grad_fn=<AddmmBackward>)
# tensor(0.4492, grad_fn=<SqueezeBackward0>)
# tensor([[1.2285]], grad_fn=<AddmmBackward>)
# tensor(0.7735, grad_fn=<SqueezeBackward0>)
# tensor([[0.0158]], grad_fn=<AddmmBackward>)
# tensor(0.5040, grad_fn=<SqueezeBackward0>)
# tensor([[0.8059]], grad_fn=<AddmmBackward>)
# tensor(0.6912, grad_fn=<SqueezeBackward0>)
# tensor([[0.0232]], grad_fn=<AddmmBackward>)
# tensor(0.5058, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0825]], grad_fn=<AddmmBackward>)
# tensor(0.2530, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3184]], grad_fn=<AddmmBackward>)
# tensor(0.4211, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8196]], grad_fn=<AddmmBackward>)
# tensor(0.3059, grad_fn=<SqueezeBackward0>)
# tensor([[0.6548]], grad_fn=<AddmmBackward>)
# tensor(0.6581, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0046]], grad_fn=<AddmmBackward>)
# tensor(0.2680, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9386]], grad_fn=<AddmmBackward>)
# tensor(0.2812, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3332]], grad_fn=<AddmmBackward>)
# tensor(0.4175, grad_fn=<SqueezeBackward0>)
# tensor([[0.3291]], grad_fn=<AddmmBackward>)
# tensor(0.5815, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4916]], grad_fn=<AddmmBackward>)
# tensor(0.3795, grad_fn=<SqueezeBackward0>)
# tensor([[-1.1380]], grad_fn=<AddmmBackward>)
# tensor(0.2427, grad_fn=<SqueezeBackward0>)
# tensor([[1.0091]], grad_fn=<AddmmBackward>)
# tensor(0.7328, grad_fn=<SqueezeBackward0>)
# tensor([[0.4700]], grad_fn=<AddmmBackward>)
# tensor(0.6154, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1352]], grad_fn=<AddmmBackward>)
# tensor(0.4663, grad_fn=<SqueezeBackward0>)
# tensor([[0.0670]], grad_fn=<AddmmBackward>)
# tensor(0.5167, grad_fn=<SqueezeBackward0>)
# tensor([[0.8711]], grad_fn=<AddmmBackward>)
# tensor(0.7050, grad_fn=<SqueezeBackward0>)
# tensor([[0.0522]], grad_fn=<AddmmBackward>)
# tensor(0.5130, grad_fn=<SqueezeBackward0>)
# tensor([[0.2555]], grad_fn=<AddmmBackward>)
# tensor(0.5635, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6950]], grad_fn=<AddmmBackward>)
# tensor(0.3329, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4790]], grad_fn=<AddmmBackward>)
# tensor(0.3825, grad_fn=<SqueezeBackward0>)
# tensor([[0.0156]], grad_fn=<AddmmBackward>)
# tensor(0.5039, grad_fn=<SqueezeBackward0>)
# tensor([[0.2925]], grad_fn=<AddmmBackward>)
# tensor(0.5726, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4532]], grad_fn=<AddmmBackward>)
# tensor(0.3886, grad_fn=<SqueezeBackward0>)
# tensor([[-1.1018]], grad_fn=<AddmmBackward>)
# tensor(0.2494, grad_fn=<SqueezeBackward0>)
# tensor([[0.0803]], grad_fn=<AddmmBackward>)
# tensor(0.5201, grad_fn=<SqueezeBackward0>)
# tensor([[0.2670]], grad_fn=<AddmmBackward>)
# tensor(0.5663, grad_fn=<SqueezeBackward0>)
# tensor([[-1.2584]], grad_fn=<AddmmBackward>)
# tensor(0.2213, grad_fn=<SqueezeBackward0>)
# tensor([[0.0810]], grad_fn=<AddmmBackward>)
# tensor(0.5202, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0453]], grad_fn=<AddmmBackward>)
# tensor(0.4887, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2314]], grad_fn=<AddmmBackward>)
# tensor(0.4424, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8406]], grad_fn=<AddmmBackward>)
# tensor(0.3014, grad_fn=<SqueezeBackward0>)
# tensor([[0.0608]], grad_fn=<AddmmBackward>)
# tensor(0.5152, grad_fn=<SqueezeBackward0>)
# tensor([[0.8965]], grad_fn=<AddmmBackward>)
# tensor(0.7102, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1581]], grad_fn=<AddmmBackward>)
# tensor(0.4606, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9741]], grad_fn=<AddmmBackward>)
# tensor(0.2741, grad_fn=<SqueezeBackward0>)
# tensor([[0.3373]], grad_fn=<AddmmBackward>)
# tensor(0.5835, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4333]], grad_fn=<AddmmBackward>)
# tensor(0.3933, grad_fn=<SqueezeBackward0>)
# tensor([[-1.4305]], grad_fn=<AddmmBackward>)
# tensor(0.1930, grad_fn=<SqueezeBackward0>)
# tensor([[0.1146]], grad_fn=<AddmmBackward>)
# tensor(0.5286, grad_fn=<SqueezeBackward0>)
# tensor([[0.4546]], grad_fn=<AddmmBackward>)
# tensor(0.6117, grad_fn=<SqueezeBackward0>)
# tensor([[0.1601]], grad_fn=<AddmmBackward>)
# tensor(0.5399, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3986]], grad_fn=<AddmmBackward>)
# tensor(0.4017, grad_fn=<SqueezeBackward0>)
# tensor([[0.6187]], grad_fn=<AddmmBackward>)
# tensor(0.6499, grad_fn=<SqueezeBackward0>)
# tensor([[0.5988]], grad_fn=<AddmmBackward>)
# tensor(0.6454, grad_fn=<SqueezeBackward0>)
# tensor([[0.7086]], grad_fn=<AddmmBackward>)
# tensor(0.6701, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0326]], grad_fn=<AddmmBackward>)
# tensor(0.4918, grad_fn=<SqueezeBackward0>)
# tensor([[0.4317]], grad_fn=<AddmmBackward>)
# tensor(0.6063, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2514]], grad_fn=<AddmmBackward>)
# tensor(0.4375, grad_fn=<SqueezeBackward0>)
# tensor([[0.5030]], grad_fn=<AddmmBackward>)
# tensor(0.6232, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1668]], grad_fn=<AddmmBackward>)
# tensor(0.4584, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5563]], grad_fn=<AddmmBackward>)
# tensor(0.3644, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2225]], grad_fn=<AddmmBackward>)
# tensor(0.4446, grad_fn=<SqueezeBackward0>)
# tensor([[0.3737]], grad_fn=<AddmmBackward>)
# tensor(0.5924, grad_fn=<SqueezeBackward0>)
# tensor([[1.0676]], grad_fn=<AddmmBackward>)
# tensor(0.7441, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3768]], grad_fn=<AddmmBackward>)
# tensor(0.4069, grad_fn=<SqueezeBackward0>)
# tensor([[0.1109]], grad_fn=<AddmmBackward>)
# tensor(0.5277, grad_fn=<SqueezeBackward0>)
# tensor([[0.4304]], grad_fn=<AddmmBackward>)
# tensor(0.6060, grad_fn=<SqueezeBackward0>)
# tensor([[0.0019]], grad_fn=<AddmmBackward>)
# tensor(0.5005, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4350]], grad_fn=<AddmmBackward>)
# tensor(0.3929, grad_fn=<SqueezeBackward0>)
# tensor([[0.7393]], grad_fn=<AddmmBackward>)
# tensor(0.6768, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0590]], grad_fn=<AddmmBackward>)
# tensor(0.4852, grad_fn=<SqueezeBackward0>)
# tensor([[0.8867]], grad_fn=<AddmmBackward>)
# tensor(0.7082, grad_fn=<SqueezeBackward0>)
# tensor([[0.0688]], grad_fn=<AddmmBackward>)
# tensor(0.5172, grad_fn=<SqueezeBackward0>)
# tensor([[0.0109]], grad_fn=<AddmmBackward>)
# tensor(0.5027, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0323]], grad_fn=<AddmmBackward>)
# tensor(0.2626, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9554]], grad_fn=<AddmmBackward>)
# tensor(0.2778, grad_fn=<SqueezeBackward0>)
# tensor([[1.3392]], grad_fn=<AddmmBackward>)
# tensor(0.7924, grad_fn=<SqueezeBackward0>)
# tensor([[0.0735]], grad_fn=<AddmmBackward>)
# tensor(0.5184, grad_fn=<SqueezeBackward0>)
# tensor([[-1.1380]], grad_fn=<AddmmBackward>)
# tensor(0.2427, grad_fn=<SqueezeBackward0>)
# tensor([[0.1922]], grad_fn=<AddmmBackward>)
# tensor(0.5479, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4625]], grad_fn=<AddmmBackward>)
# tensor(0.3864, grad_fn=<SqueezeBackward0>)
# tensor([[1.6730]], grad_fn=<AddmmBackward>)
# tensor(0.8420, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6123]], grad_fn=<AddmmBackward>)
# tensor(0.3515, grad_fn=<SqueezeBackward0>)
# tensor([[0.4167]], grad_fn=<AddmmBackward>)
# tensor(0.6027, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4678]], grad_fn=<AddmmBackward>)
# tensor(0.3851, grad_fn=<SqueezeBackward0>)
# tensor([[0.0268]], grad_fn=<AddmmBackward>)
# tensor(0.5067, grad_fn=<SqueezeBackward0>)
# tensor([[0.5113]], grad_fn=<AddmmBackward>)
# tensor(0.6251, grad_fn=<SqueezeBackward0>)
# tensor([[0.4222]], grad_fn=<AddmmBackward>)
# tensor(0.6040, grad_fn=<SqueezeBackward0>)
# tensor([[0.0268]], grad_fn=<AddmmBackward>)
# tensor(0.5067, grad_fn=<SqueezeBackward0>)
# tensor([[0.2824]], grad_fn=<AddmmBackward>)
# tensor(0.5701, grad_fn=<SqueezeBackward0>)
# tensor([[0.0340]], grad_fn=<AddmmBackward>)
# tensor(0.5085, grad_fn=<SqueezeBackward0>)
# tensor([[0.3133]], grad_fn=<AddmmBackward>)
# tensor(0.5777, grad_fn=<SqueezeBackward0>)
# tensor([[0.2634]], grad_fn=<AddmmBackward>)
# tensor(0.5655, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3566]], grad_fn=<AddmmBackward>)
# tensor(0.4118, grad_fn=<SqueezeBackward0>)
# tensor([[0.2601]], grad_fn=<AddmmBackward>)
# tensor(0.5647, grad_fn=<SqueezeBackward0>)
# tensor([[0.1276]], grad_fn=<AddmmBackward>)
# tensor(0.5319, grad_fn=<SqueezeBackward0>)
# tensor([[0.0477]], grad_fn=<AddmmBackward>)
# tensor(0.5119, grad_fn=<SqueezeBackward0>)
# tensor([[0.4673]], grad_fn=<AddmmBackward>)
# tensor(0.6147, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5022]], grad_fn=<AddmmBackward>)
# tensor(0.3770, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2530]], grad_fn=<AddmmBackward>)
# tensor(0.4371, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0684]], grad_fn=<AddmmBackward>)
# tensor(0.2557, grad_fn=<SqueezeBackward0>)
# tensor([[0.6257]], grad_fn=<AddmmBackward>)
# tensor(0.6515, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2687]], grad_fn=<AddmmBackward>)
# tensor(0.4332, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5481]], grad_fn=<AddmmBackward>)
# tensor(0.3663, grad_fn=<SqueezeBackward0>)
# tensor([[0.1476]], grad_fn=<AddmmBackward>)
# tensor(0.5368, grad_fn=<SqueezeBackward0>)
# tensor([[0.4866]], grad_fn=<AddmmBackward>)
# tensor(0.6193, grad_fn=<SqueezeBackward0>)
# tensor([[0.9534]], grad_fn=<AddmmBackward>)
# tensor(0.7218, grad_fn=<SqueezeBackward0>)
# tensor([[1.5516]], grad_fn=<AddmmBackward>)
# tensor(0.8251, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3441]], grad_fn=<AddmmBackward>)
# tensor(0.4148, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1581]], grad_fn=<AddmmBackward>)
# tensor(0.4606, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6636]], grad_fn=<AddmmBackward>)
# tensor(0.3399, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0762]], grad_fn=<AddmmBackward>)
# tensor(0.2542, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0308]], grad_fn=<AddmmBackward>)
# tensor(0.4923, grad_fn=<SqueezeBackward0>)
# tensor([[0.7033]], grad_fn=<AddmmBackward>)
# tensor(0.6689, grad_fn=<SqueezeBackward0>)
# tensor([[0.4392]], grad_fn=<AddmmBackward>)
# tensor(0.6081, grad_fn=<SqueezeBackward0>)
# tensor([[0.2801]], grad_fn=<AddmmBackward>)
# tensor(0.5696, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5402]], grad_fn=<AddmmBackward>)
# tensor(0.3681, grad_fn=<SqueezeBackward0>)
# tensor([[0.4554]], grad_fn=<AddmmBackward>)
# tensor(0.6119, grad_fn=<SqueezeBackward0>)
# tensor([[0.8850]], grad_fn=<AddmmBackward>)
# tensor(0.7079, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0812]], grad_fn=<AddmmBackward>)
# tensor(0.4797, grad_fn=<SqueezeBackward0>)
# tensor([[0.7709]], grad_fn=<AddmmBackward>)
# tensor(0.6837, grad_fn=<SqueezeBackward0>)
# tensor([[0.6209]], grad_fn=<AddmmBackward>)
# tensor(0.6504, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0111]], grad_fn=<AddmmBackward>)
# tensor(0.4972, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1311]], grad_fn=<AddmmBackward>)
# tensor(0.4673, grad_fn=<SqueezeBackward0>)
# tensor([[0.7275]], grad_fn=<AddmmBackward>)
# tensor(0.6743, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3098]], grad_fn=<AddmmBackward>)
# tensor(0.4232, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0779]], grad_fn=<AddmmBackward>)
# tensor(0.4805, grad_fn=<SqueezeBackward0>)
# tensor([[0.1544]], grad_fn=<AddmmBackward>)
# tensor(0.5385, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8796]], grad_fn=<AddmmBackward>)
# tensor(0.2933, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0605]], grad_fn=<AddmmBackward>)
# tensor(0.4849, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5521]], grad_fn=<AddmmBackward>)
# tensor(0.3654, grad_fn=<SqueezeBackward0>)
# tensor([[0.3123]], grad_fn=<AddmmBackward>)
# tensor(0.5774, grad_fn=<SqueezeBackward0>)
# tensor([[0.7940]], grad_fn=<AddmmBackward>)
# tensor(0.6887, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1639]], grad_fn=<AddmmBackward>)
# tensor(0.4591, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7404]], grad_fn=<AddmmBackward>)
# tensor(0.3229, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2184]], grad_fn=<AddmmBackward>)
# tensor(0.4456, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2007]], grad_fn=<AddmmBackward>)
# tensor(0.4500, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4660]], grad_fn=<AddmmBackward>)
# tensor(0.3856, grad_fn=<SqueezeBackward0>)
# tensor([[0.2707]], grad_fn=<AddmmBackward>)
# tensor(0.5673, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9727]], grad_fn=<AddmmBackward>)
# tensor(0.2743, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0592]], grad_fn=<AddmmBackward>)
# tensor(0.4852, grad_fn=<SqueezeBackward0>)
# tensor([[0.1286]], grad_fn=<AddmmBackward>)
# tensor(0.5321, grad_fn=<SqueezeBackward0>)
# tensor([[0.2990]], grad_fn=<AddmmBackward>)
# tensor(0.5742, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3441]], grad_fn=<AddmmBackward>)
# tensor(0.4148, grad_fn=<SqueezeBackward0>)
# tensor([[2.1232]], grad_fn=<AddmmBackward>)
# tensor(0.8931, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5049]], grad_fn=<AddmmBackward>)
# tensor(0.3764, grad_fn=<SqueezeBackward0>)
# tensor([[0.1316]], grad_fn=<AddmmBackward>)
# tensor(0.5328, grad_fn=<SqueezeBackward0>)
# tensor([[0.5710]], grad_fn=<AddmmBackward>)
# tensor(0.6390, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1115]], grad_fn=<AddmmBackward>)
# tensor(0.4721, grad_fn=<SqueezeBackward0>)
# tensor([[0.5765]], grad_fn=<AddmmBackward>)
# tensor(0.6403, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4273]], grad_fn=<AddmmBackward>)
# tensor(0.3948, grad_fn=<SqueezeBackward0>)
# tensor([[0.8847]], grad_fn=<AddmmBackward>)
# tensor(0.7078, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6351]], grad_fn=<AddmmBackward>)
# tensor(0.3464, grad_fn=<SqueezeBackward0>)
# tensor([[0.3382]], grad_fn=<AddmmBackward>)
# tensor(0.5837, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1982]], grad_fn=<AddmmBackward>)
# tensor(0.4506, grad_fn=<SqueezeBackward0>)
# tensor([[-1.1726]], grad_fn=<AddmmBackward>)
# tensor(0.2364, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1223]], grad_fn=<AddmmBackward>)
# tensor(0.4695, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4790]], grad_fn=<AddmmBackward>)
# tensor(0.3825, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3441]], grad_fn=<AddmmBackward>)
# tensor(0.4148, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1992]], grad_fn=<AddmmBackward>)
# tensor(0.4504, grad_fn=<SqueezeBackward0>)
# tensor([[0.5854]], grad_fn=<AddmmBackward>)
# tensor(0.6423, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0520]], grad_fn=<AddmmBackward>)
# tensor(0.2588, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8439]], grad_fn=<AddmmBackward>)
# tensor(0.3007, grad_fn=<SqueezeBackward0>)
# tensor([[0.2533]], grad_fn=<AddmmBackward>)
# tensor(0.5630, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5308]], grad_fn=<AddmmBackward>)
# tensor(0.3703, grad_fn=<SqueezeBackward0>)
# tensor([[1.5636]], grad_fn=<AddmmBackward>)
# tensor(0.8269, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7020]], grad_fn=<AddmmBackward>)
# tensor(0.3314, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2558]], grad_fn=<AddmmBackward>)
# tensor(0.4364, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5298]], grad_fn=<AddmmBackward>)
# tensor(0.3706, grad_fn=<SqueezeBackward0>)
# tensor([[0.1813]], grad_fn=<AddmmBackward>)
# tensor(0.5452, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0622]], grad_fn=<AddmmBackward>)
# tensor(0.4845, grad_fn=<SqueezeBackward0>)
# tensor([[0.9226]], grad_fn=<AddmmBackward>)
# tensor(0.7156, grad_fn=<SqueezeBackward0>)
# tensor([[0.9649]], grad_fn=<AddmmBackward>)
# tensor(0.7241, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0214]], grad_fn=<AddmmBackward>)
# tensor(0.4947, grad_fn=<SqueezeBackward0>)
# tensor([[0.6704]], grad_fn=<AddmmBackward>)
# tensor(0.6616, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9571]], grad_fn=<AddmmBackward>)
# tensor(0.2775, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5043]], grad_fn=<AddmmBackward>)
# tensor(0.3765, grad_fn=<SqueezeBackward0>)
# tensor([[0.7186]], grad_fn=<AddmmBackward>)
# tensor(0.6723, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9799]], grad_fn=<AddmmBackward>)
# tensor(0.2729, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5926]], grad_fn=<AddmmBackward>)
# tensor(0.3560, grad_fn=<SqueezeBackward0>)
# tensor([[-1.3370]], grad_fn=<AddmmBackward>)
# tensor(0.2080, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0197]], grad_fn=<AddmmBackward>)
# tensor(0.2651, grad_fn=<SqueezeBackward0>)
# tensor([[1.7949]], grad_fn=<AddmmBackward>)
# tensor(0.8575, grad_fn=<SqueezeBackward0>)
# tensor([[0.4554]], grad_fn=<AddmmBackward>)
# tensor(0.6119, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1635]], grad_fn=<AddmmBackward>)
# tensor(0.4592, grad_fn=<SqueezeBackward0>)
# tensor([[0.4111]], grad_fn=<AddmmBackward>)
# tensor(0.6013, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2468]], grad_fn=<AddmmBackward>)
# tensor(0.4386, grad_fn=<SqueezeBackward0>)
# tensor([[0.0061]], grad_fn=<AddmmBackward>)
# tensor(0.5015, grad_fn=<SqueezeBackward0>)
# tensor([[-1.2782]], grad_fn=<AddmmBackward>)
# tensor(0.2179, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8973]], grad_fn=<AddmmBackward>)
# tensor(0.2896, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0041]], grad_fn=<AddmmBackward>)
# tensor(0.4990, grad_fn=<SqueezeBackward0>)
# tensor([[0.6910]], grad_fn=<AddmmBackward>)
# tensor(0.6662, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1381]], grad_fn=<AddmmBackward>)
# tensor(0.4655, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4278]], grad_fn=<AddmmBackward>)
# tensor(0.3946, grad_fn=<SqueezeBackward0>)
# tensor([[0.1995]], grad_fn=<AddmmBackward>)
# tensor(0.5497, grad_fn=<SqueezeBackward0>)
# tensor([[1.2012]], grad_fn=<AddmmBackward>)
# tensor(0.7687, grad_fn=<SqueezeBackward0>)
# tensor([[0.0732]], grad_fn=<AddmmBackward>)
# tensor(0.5183, grad_fn=<SqueezeBackward0>)
# tensor([[0.0830]], grad_fn=<AddmmBackward>)
# tensor(0.5207, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8083]], grad_fn=<AddmmBackward>)
# tensor(0.3083, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0695]], grad_fn=<AddmmBackward>)
# tensor(0.4826, grad_fn=<SqueezeBackward0>)
# tensor([[0.8060]], grad_fn=<AddmmBackward>)
# tensor(0.6913, grad_fn=<SqueezeBackward0>)
# tensor([[0.3070]], grad_fn=<AddmmBackward>)
# tensor(0.5762, grad_fn=<SqueezeBackward0>)
# tensor([[0.3799]], grad_fn=<AddmmBackward>)
# tensor(0.5939, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6792]], grad_fn=<AddmmBackward>)
# tensor(0.3364, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2813]], grad_fn=<AddmmBackward>)
# tensor(0.4301, grad_fn=<SqueezeBackward0>)
# tensor([[0.1277]], grad_fn=<AddmmBackward>)
# tensor(0.5319, grad_fn=<SqueezeBackward0>)
# tensor([[0.7912]], grad_fn=<AddmmBackward>)
# tensor(0.6881, grad_fn=<SqueezeBackward0>)
# tensor([[0.3985]], grad_fn=<AddmmBackward>)
# tensor(0.5983, grad_fn=<SqueezeBackward0>)
# tensor([[0.3070]], grad_fn=<AddmmBackward>)
# tensor(0.5762, grad_fn=<SqueezeBackward0>)
# tensor([[0.0540]], grad_fn=<AddmmBackward>)
# tensor(0.5135, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5624]], grad_fn=<AddmmBackward>)
# tensor(0.3630, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6230]], grad_fn=<AddmmBackward>)
# tensor(0.3491, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0679]], grad_fn=<AddmmBackward>)
# tensor(0.4830, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8524]], grad_fn=<AddmmBackward>)
# tensor(0.2989, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3789]], grad_fn=<AddmmBackward>)
# tensor(0.4064, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2530]], grad_fn=<AddmmBackward>)
# tensor(0.4371, grad_fn=<SqueezeBackward0>)
# tensor([[0.6118]], grad_fn=<AddmmBackward>)
# tensor(0.6484, grad_fn=<SqueezeBackward0>)
# tensor([[0.5498]], grad_fn=<AddmmBackward>)
# tensor(0.6341, grad_fn=<SqueezeBackward0>)
# tensor([[0.3592]], grad_fn=<AddmmBackward>)
# tensor(0.5888, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2092]], grad_fn=<AddmmBackward>)
# tensor(0.4479, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0704]], grad_fn=<AddmmBackward>)
# tensor(0.4824, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3033]], grad_fn=<AddmmBackward>)
# tensor(0.4248, grad_fn=<SqueezeBackward0>)
# tensor([[0.5122]], grad_fn=<AddmmBackward>)
# tensor(0.6253, grad_fn=<SqueezeBackward0>)
# tensor([[0.9118]], grad_fn=<AddmmBackward>)
# tensor(0.7134, grad_fn=<SqueezeBackward0>)
# tensor([[-1.1107]], grad_fn=<AddmmBackward>)
# tensor(0.2477, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0836]], grad_fn=<AddmmBackward>)
# tensor(0.4791, grad_fn=<SqueezeBackward0>)
# tensor([[0.0287]], grad_fn=<AddmmBackward>)
# tensor(0.5072, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0155]], grad_fn=<AddmmBackward>)
# tensor(0.4961, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0332]], grad_fn=<AddmmBackward>)
# tensor(0.4917, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5267]], grad_fn=<AddmmBackward>)
# tensor(0.3713, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5348]], grad_fn=<AddmmBackward>)
# tensor(0.3694, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7948]], grad_fn=<AddmmBackward>)
# tensor(0.3111, grad_fn=<SqueezeBackward0>)
# tensor([[0.6322]], grad_fn=<AddmmBackward>)
# tensor(0.6530, grad_fn=<SqueezeBackward0>)
# tensor([[1.5225]], grad_fn=<AddmmBackward>)
# tensor(0.8209, grad_fn=<SqueezeBackward0>)
# tensor([[0.0273]], grad_fn=<AddmmBackward>)
# tensor(0.5068, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2874]], grad_fn=<AddmmBackward>)
# tensor(0.4286, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2035]], grad_fn=<AddmmBackward>)
# tensor(0.4493, grad_fn=<SqueezeBackward0>)
# tensor([[0.6354]], grad_fn=<AddmmBackward>)
# tensor(0.6537, grad_fn=<SqueezeBackward0>)
# tensor([[0.4397]], grad_fn=<AddmmBackward>)
# tensor(0.6082, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6589]], grad_fn=<AddmmBackward>)
# tensor(0.3410, grad_fn=<SqueezeBackward0>)
# tensor([[0.2385]], grad_fn=<AddmmBackward>)
# tensor(0.5593, grad_fn=<SqueezeBackward0>)
# tensor([[0.1250]], grad_fn=<AddmmBackward>)
# tensor(0.5312, grad_fn=<SqueezeBackward0>)
# tensor([[0.4142]], grad_fn=<AddmmBackward>)
# tensor(0.6021, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3089]], grad_fn=<AddmmBackward>)
# tensor(0.4234, grad_fn=<SqueezeBackward0>)
# tensor([[0.3016]], grad_fn=<AddmmBackward>)
# tensor(0.5748, grad_fn=<SqueezeBackward0>)
# tensor([[0.5606]], grad_fn=<AddmmBackward>)
# tensor(0.6366, grad_fn=<SqueezeBackward0>)
# tensor([[0.8168]], grad_fn=<AddmmBackward>)
# tensor(0.6936, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3443]], grad_fn=<AddmmBackward>)
# tensor(0.4148, grad_fn=<SqueezeBackward0>)
# tensor([[0.5337]], grad_fn=<AddmmBackward>)
# tensor(0.6303, grad_fn=<SqueezeBackward0>)
# tensor([[0.2786]], grad_fn=<AddmmBackward>)
# tensor(0.5692, grad_fn=<SqueezeBackward0>)
# tensor([[0.6184]], grad_fn=<AddmmBackward>)
# tensor(0.6498, grad_fn=<SqueezeBackward0>)
# tensor([[0.7275]], grad_fn=<AddmmBackward>)
# tensor(0.6743, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6137]], grad_fn=<AddmmBackward>)
# tensor(0.3512, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2743]], grad_fn=<AddmmBackward>)
# tensor(0.4319, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2035]], grad_fn=<AddmmBackward>)
# tensor(0.4493, grad_fn=<SqueezeBackward0>)
# tensor([[0.1106]], grad_fn=<AddmmBackward>)
# tensor(0.5276, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1681]], grad_fn=<AddmmBackward>)
# tensor(0.4581, grad_fn=<SqueezeBackward0>)
# tensor([[0.5402]], grad_fn=<AddmmBackward>)
# tensor(0.6319, grad_fn=<SqueezeBackward0>)
# tensor([[0.6737]], grad_fn=<AddmmBackward>)
# tensor(0.6623, grad_fn=<SqueezeBackward0>)
# tensor([[0.0613]], grad_fn=<AddmmBackward>)
# tensor(0.5153, grad_fn=<SqueezeBackward0>)
# tensor([[0.7732]], grad_fn=<AddmmBackward>)
# tensor(0.6842, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7804]], grad_fn=<AddmmBackward>)
# tensor(0.3142, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1033]], grad_fn=<AddmmBackward>)
# tensor(0.4742, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6525]], grad_fn=<AddmmBackward>)
# tensor(0.3424, grad_fn=<SqueezeBackward0>)
# tensor([[0.5499]], grad_fn=<AddmmBackward>)
# tensor(0.6341, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1533]], grad_fn=<AddmmBackward>)
# tensor(0.4617, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1425]], grad_fn=<AddmmBackward>)
# tensor(0.4644, grad_fn=<SqueezeBackward0>)
# tensor([[0.5606]], grad_fn=<AddmmBackward>)
# tensor(0.6366, grad_fn=<SqueezeBackward0>)
# tensor([[0.0557]], grad_fn=<AddmmBackward>)
# tensor(0.5139, grad_fn=<SqueezeBackward0>)
# tensor([[0.1146]], grad_fn=<AddmmBackward>)
# tensor(0.5286, grad_fn=<SqueezeBackward0>)
# tensor([[0.3838]], grad_fn=<AddmmBackward>)
# tensor(0.5948, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1721]], grad_fn=<AddmmBackward>)
# tensor(0.4571, grad_fn=<SqueezeBackward0>)
# tensor([[0.7086]], grad_fn=<AddmmBackward>)
# tensor(0.6701, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5262]], grad_fn=<AddmmBackward>)
# tensor(0.3714, grad_fn=<SqueezeBackward0>)
# tensor([[0.0267]], grad_fn=<AddmmBackward>)
# tensor(0.5067, grad_fn=<SqueezeBackward0>)
# tensor([[0.3737]], grad_fn=<AddmmBackward>)
# tensor(0.5924, grad_fn=<SqueezeBackward0>)
# tensor([[0.3070]], grad_fn=<AddmmBackward>)
# tensor(0.5761, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1069]], grad_fn=<AddmmBackward>)
# tensor(0.4733, grad_fn=<SqueezeBackward0>)
# tensor([[0.3071]], grad_fn=<AddmmBackward>)
# tensor(0.5762, grad_fn=<SqueezeBackward0>)
# tensor([[0.5932]], grad_fn=<AddmmBackward>)
# tensor(0.6441, grad_fn=<SqueezeBackward0>)
# tensor([[0.0993]], grad_fn=<AddmmBackward>)
# tensor(0.5248, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5984]], grad_fn=<AddmmBackward>)
# tensor(0.3547, grad_fn=<SqueezeBackward0>)
# tensor([[0.2785]], grad_fn=<AddmmBackward>)
# tensor(0.5692, grad_fn=<SqueezeBackward0>)
# tensor([[0.7291]], grad_fn=<AddmmBackward>)
# tensor(0.6746, grad_fn=<SqueezeBackward0>)
# tensor([[0.4350]], grad_fn=<AddmmBackward>)
# tensor(0.6071, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0014]], grad_fn=<AddmmBackward>)
# tensor(0.2687, grad_fn=<SqueezeBackward0>)
# tensor([[0.2824]], grad_fn=<AddmmBackward>)
# tensor(0.5701, grad_fn=<SqueezeBackward0>)
# tensor([[0.3782]], grad_fn=<AddmmBackward>)
# tensor(0.5934, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1510]], grad_fn=<AddmmBackward>)
# tensor(0.4623, grad_fn=<SqueezeBackward0>)
# tensor([[-1.3536]], grad_fn=<AddmmBackward>)
# tensor(0.2053, grad_fn=<SqueezeBackward0>)
# tensor([[0.4885]], grad_fn=<AddmmBackward>)
# tensor(0.6198, grad_fn=<SqueezeBackward0>)
# tensor([[0.1860]], grad_fn=<AddmmBackward>)
# tensor(0.5464, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0447]], grad_fn=<AddmmBackward>)
# tensor(0.4888, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0323]], grad_fn=<AddmmBackward>)
# tensor(0.2626, grad_fn=<SqueezeBackward0>)
# tensor([[1.6204]], grad_fn=<AddmmBackward>)
# tensor(0.8349, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3780]], grad_fn=<AddmmBackward>)
# tensor(0.4066, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0024]], grad_fn=<AddmmBackward>)
# tensor(0.4994, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9219]], grad_fn=<AddmmBackward>)
# tensor(0.2846, grad_fn=<SqueezeBackward0>)
# tensor([[0.0557]], grad_fn=<AddmmBackward>)
# tensor(0.5139, grad_fn=<SqueezeBackward0>)
# tensor([[0.0347]], grad_fn=<AddmmBackward>)
# tensor(0.5087, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1223]], grad_fn=<AddmmBackward>)
# tensor(0.4695, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1136]], grad_fn=<AddmmBackward>)
# tensor(0.4716, grad_fn=<SqueezeBackward0>)
# tensor([[0.2291]], grad_fn=<AddmmBackward>)
# tensor(0.5570, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3691]], grad_fn=<AddmmBackward>)
# tensor(0.4088, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7256]], grad_fn=<AddmmBackward>)
# tensor(0.3262, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0762]], grad_fn=<AddmmBackward>)
# tensor(0.2542, grad_fn=<SqueezeBackward0>)
# tensor([[0.0635]], grad_fn=<AddmmBackward>)
# tensor(0.5159, grad_fn=<SqueezeBackward0>)
# tensor([[0.2861]], grad_fn=<AddmmBackward>)
# tensor(0.5710, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5298]], grad_fn=<AddmmBackward>)
# tensor(0.3706, grad_fn=<SqueezeBackward0>)
# tensor([[0.9707]], grad_fn=<AddmmBackward>)
# tensor(0.7253, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2155]], grad_fn=<AddmmBackward>)
# tensor(0.4463, grad_fn=<SqueezeBackward0>)
# tensor([[1.3942]], grad_fn=<AddmmBackward>)
# tensor(0.8013, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5216]], grad_fn=<AddmmBackward>)
# tensor(0.3725, grad_fn=<SqueezeBackward0>)
# tensor([[0.1243]], grad_fn=<AddmmBackward>)
# tensor(0.5310, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1253]], grad_fn=<AddmmBackward>)
# tensor(0.4687, grad_fn=<SqueezeBackward0>)
# tensor([[0.6245]], grad_fn=<AddmmBackward>)
# tensor(0.6512, grad_fn=<SqueezeBackward0>)
# tensor([[0.5341]], grad_fn=<AddmmBackward>)
# tensor(0.6304, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9799]], grad_fn=<AddmmBackward>)
# tensor(0.2729, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9158]], grad_fn=<AddmmBackward>)
# tensor(0.2858, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4127]], grad_fn=<AddmmBackward>)
# tensor(0.3983, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6593]], grad_fn=<AddmmBackward>)
# tensor(0.3409, grad_fn=<SqueezeBackward0>)
# tensor([[0.0647]], grad_fn=<AddmmBackward>)
# tensor(0.5162, grad_fn=<SqueezeBackward0>)
# tensor([[0.3375]], grad_fn=<AddmmBackward>)
# tensor(0.5836, grad_fn=<SqueezeBackward0>)
# tensor([[0.1667]], grad_fn=<AddmmBackward>)
# tensor(0.5416, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1293]], grad_fn=<AddmmBackward>)
# tensor(0.4677, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0309]], grad_fn=<AddmmBackward>)
# tensor(0.4923, grad_fn=<SqueezeBackward0>)
# tensor([[0.1328]], grad_fn=<AddmmBackward>)
# tensor(0.5332, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6586]], grad_fn=<AddmmBackward>)
# tensor(0.3410, grad_fn=<SqueezeBackward0>)
# tensor([[0.0056]], grad_fn=<AddmmBackward>)
# tensor(0.5014, grad_fn=<SqueezeBackward0>)
# tensor([[0.2214]], grad_fn=<AddmmBackward>)
# tensor(0.5551, grad_fn=<SqueezeBackward0>)
# tensor([[0.3710]], grad_fn=<AddmmBackward>)
# tensor(0.5917, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7079]], grad_fn=<AddmmBackward>)
# tensor(0.3301, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5246]], grad_fn=<AddmmBackward>)
# tensor(0.3718, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9917]], grad_fn=<AddmmBackward>)
# tensor(0.2706, grad_fn=<SqueezeBackward0>)
# tensor([[0.3887]], grad_fn=<AddmmBackward>)
# tensor(0.5960, grad_fn=<SqueezeBackward0>)
# tensor([[0.1058]], grad_fn=<AddmmBackward>)
# tensor(0.5264, grad_fn=<SqueezeBackward0>)
# tensor([[0.7222]], grad_fn=<AddmmBackward>)
# tensor(0.6731, grad_fn=<SqueezeBackward0>)
# tensor([[0.0829]], grad_fn=<AddmmBackward>)
# tensor(0.5207, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1363]], grad_fn=<AddmmBackward>)
# tensor(0.4660, grad_fn=<SqueezeBackward0>)
# tensor([[0.2824]], grad_fn=<AddmmBackward>)
# tensor(0.5701, grad_fn=<SqueezeBackward0>)
# tensor([[0.1220]], grad_fn=<AddmmBackward>)
# tensor(0.5305, grad_fn=<SqueezeBackward0>)
# tensor([[0.3108]], grad_fn=<AddmmBackward>)
# tensor(0.5771, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0112]], grad_fn=<AddmmBackward>)
# tensor(0.4972, grad_fn=<SqueezeBackward0>)
# tensor([[0.8681]], grad_fn=<AddmmBackward>)
# tensor(0.7043, grad_fn=<SqueezeBackward0>)
# tensor([[0.2975]], grad_fn=<AddmmBackward>)
# tensor(0.5738, grad_fn=<SqueezeBackward0>)
# tensor([[0.5080]], grad_fn=<AddmmBackward>)
# tensor(0.6243, grad_fn=<SqueezeBackward0>)
# tensor([[0.2800]], grad_fn=<AddmmBackward>)
# tensor(0.5696, grad_fn=<SqueezeBackward0>)
# tensor([[0.6260]], grad_fn=<AddmmBackward>)
# tensor(0.6516, grad_fn=<SqueezeBackward0>)
# tensor([[0.6953]], grad_fn=<AddmmBackward>)
# tensor(0.6672, grad_fn=<SqueezeBackward0>)
# tensor([[0.8465]], grad_fn=<AddmmBackward>)
# tensor(0.6998, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1929]], grad_fn=<AddmmBackward>)
# tensor(0.4519, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2380]], grad_fn=<AddmmBackward>)
# tensor(0.4408, grad_fn=<SqueezeBackward0>)
# tensor([[0.0635]], grad_fn=<AddmmBackward>)
# tensor(0.5159, grad_fn=<SqueezeBackward0>)
# tensor([[0.3298]], grad_fn=<AddmmBackward>)
# tensor(0.5817, grad_fn=<SqueezeBackward0>)
# tensor([[0.2535]], grad_fn=<AddmmBackward>)
# tensor(0.5630, grad_fn=<SqueezeBackward0>)
# tensor([[0.0670]], grad_fn=<AddmmBackward>)
# tensor(0.5167, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7352]], grad_fn=<AddmmBackward>)
# tensor(0.3241, grad_fn=<SqueezeBackward0>)
# tensor([[0.8894]], grad_fn=<AddmmBackward>)
# tensor(0.7088, grad_fn=<SqueezeBackward0>)
# tensor([[0.6600]], grad_fn=<AddmmBackward>)
# tensor(0.6593, grad_fn=<SqueezeBackward0>)
# tensor([[0.4076]], grad_fn=<AddmmBackward>)
# tensor(0.6005, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6026]], grad_fn=<AddmmBackward>)
# tensor(0.3538, grad_fn=<SqueezeBackward0>)
# tensor([[0.1982]], grad_fn=<AddmmBackward>)
# tensor(0.5494, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5537]], grad_fn=<AddmmBackward>)
# tensor(0.3650, grad_fn=<SqueezeBackward0>)
# tensor([[0.7646]], grad_fn=<AddmmBackward>)
# tensor(0.6824, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7971]], grad_fn=<AddmmBackward>)
# tensor(0.3106, grad_fn=<SqueezeBackward0>)
# tensor([[0.2425]], grad_fn=<AddmmBackward>)
# tensor(0.5603, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6259]], grad_fn=<AddmmBackward>)
# tensor(0.3484, grad_fn=<SqueezeBackward0>)
# tensor([[0.5499]], grad_fn=<AddmmBackward>)
# tensor(0.6341, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2038]], grad_fn=<AddmmBackward>)
# tensor(0.4492, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2361]], grad_fn=<AddmmBackward>)
# tensor(0.4413, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0163]], grad_fn=<AddmmBackward>)
# tensor(0.4959, grad_fn=<SqueezeBackward0>)
# tensor([[2.1232]], grad_fn=<AddmmBackward>)
# tensor(0.8931, grad_fn=<SqueezeBackward0>)
# tensor([[0.5881]], grad_fn=<AddmmBackward>)
# tensor(0.6429, grad_fn=<SqueezeBackward0>)
# tensor([[0.9730]], grad_fn=<AddmmBackward>)
# tensor(0.7257, grad_fn=<SqueezeBackward0>)
# tensor([[0.8401]], grad_fn=<AddmmBackward>)
# tensor(0.6985, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7256]], grad_fn=<AddmmBackward>)
# tensor(0.3262, grad_fn=<SqueezeBackward0>)
# tensor([[0.0131]], grad_fn=<AddmmBackward>)
# tensor(0.5033, grad_fn=<SqueezeBackward0>)
# tensor([[0.5133]], grad_fn=<AddmmBackward>)
# tensor(0.6256, grad_fn=<SqueezeBackward0>)
# tensor([[0.0488]], grad_fn=<AddmmBackward>)
# tensor(0.5122, grad_fn=<SqueezeBackward0>)
# tensor([[0.8788]], grad_fn=<AddmmBackward>)
# tensor(0.7066, grad_fn=<SqueezeBackward0>)
# tensor([[0.5606]], grad_fn=<AddmmBackward>)
# tensor(0.6366, grad_fn=<SqueezeBackward0>)
# tensor([[0.3748]], grad_fn=<AddmmBackward>)
# tensor(0.5926, grad_fn=<SqueezeBackward0>)
# tensor([[0.0345]], grad_fn=<AddmmBackward>)
# tensor(0.5086, grad_fn=<SqueezeBackward0>)
# tensor([[0.1299]], grad_fn=<AddmmBackward>)
# tensor(0.5324, grad_fn=<SqueezeBackward0>)
# tensor([[0.2087]], grad_fn=<AddmmBackward>)
# tensor(0.5520, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2474]], grad_fn=<AddmmBackward>)
# tensor(0.4385, grad_fn=<SqueezeBackward0>)
# tensor([[0.2116]], grad_fn=<AddmmBackward>)
# tensor(0.5527, grad_fn=<SqueezeBackward0>)
# tensor([[0.3424]], grad_fn=<AddmmBackward>)
# tensor(0.5848, grad_fn=<SqueezeBackward0>)
# tensor([[0.4916]], grad_fn=<AddmmBackward>)
# tensor(0.6205, grad_fn=<SqueezeBackward0>)
# tensor([[1.0680]], grad_fn=<AddmmBackward>)
# tensor(0.7442, grad_fn=<SqueezeBackward0>)
# tensor([[0.9252]], grad_fn=<AddmmBackward>)
# tensor(0.7161, grad_fn=<SqueezeBackward0>)
# tensor([[0.2248]], grad_fn=<AddmmBackward>)
# tensor(0.5560, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7226]], grad_fn=<AddmmBackward>)
# tensor(0.3268, grad_fn=<SqueezeBackward0>)
# tensor([[0.7489]], grad_fn=<AddmmBackward>)
# tensor(0.6789, grad_fn=<SqueezeBackward0>)
# tensor([[0.4356]], grad_fn=<AddmmBackward>)
# tensor(0.6072, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0632]], grad_fn=<AddmmBackward>)
# tensor(0.4842, grad_fn=<SqueezeBackward0>)
# tensor([[0.5783]], grad_fn=<AddmmBackward>)
# tensor(0.6407, grad_fn=<SqueezeBackward0>)
# tensor([[0.3489]], grad_fn=<AddmmBackward>)
# tensor(0.5863, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1256]], grad_fn=<AddmmBackward>)
# tensor(0.4686, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5122]], grad_fn=<AddmmBackward>)
# tensor(0.3747, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2986]], grad_fn=<AddmmBackward>)
# tensor(0.4259, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1998]], grad_fn=<AddmmBackward>)
# tensor(0.4502, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0520]], grad_fn=<AddmmBackward>)
# tensor(0.2588, grad_fn=<SqueezeBackward0>)
# tensor([[0.4700]], grad_fn=<AddmmBackward>)
# tensor(0.6154, grad_fn=<SqueezeBackward0>)
# tensor([[0.9733]], grad_fn=<AddmmBackward>)
# tensor(0.7258, grad_fn=<SqueezeBackward0>)
# tensor([[0.8526]], grad_fn=<AddmmBackward>)
# tensor(0.7011, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9799]], grad_fn=<AddmmBackward>)
# tensor(0.2729, grad_fn=<SqueezeBackward0>)
# tensor([[1.2594]], grad_fn=<AddmmBackward>)
# tensor(0.7789, grad_fn=<SqueezeBackward0>)
# tensor([[0.1922]], grad_fn=<AddmmBackward>)
# tensor(0.5479, grad_fn=<SqueezeBackward0>)
# tensor([[0.2226]], grad_fn=<AddmmBackward>)
# tensor(0.5554, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5697]], grad_fn=<AddmmBackward>)
# tensor(0.3613, grad_fn=<SqueezeBackward0>)
# tensor([[0.5567]], grad_fn=<AddmmBackward>)
# tensor(0.6357, grad_fn=<SqueezeBackward0>)
# tensor([[0.1243]], grad_fn=<AddmmBackward>)
# tensor(0.5310, grad_fn=<SqueezeBackward0>)
# tensor([[0.7468]], grad_fn=<AddmmBackward>)
# tensor(0.6785, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3635]], grad_fn=<AddmmBackward>)
# tensor(0.4101, grad_fn=<SqueezeBackward0>)
# tensor([[0.8669]], grad_fn=<AddmmBackward>)
# tensor(0.7041, grad_fn=<SqueezeBackward0>)
# tensor([[0.1799]], grad_fn=<AddmmBackward>)
# tensor(0.5448, grad_fn=<SqueezeBackward0>)
# tensor([[-1.5380]], grad_fn=<AddmmBackward>)
# tensor(0.1768, grad_fn=<SqueezeBackward0>)
# tensor([[0.6918]], grad_fn=<AddmmBackward>)
# tensor(0.6664, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6351]], grad_fn=<AddmmBackward>)
# tensor(0.3464, grad_fn=<SqueezeBackward0>)
# tensor([[0.3533]], grad_fn=<AddmmBackward>)
# tensor(0.5874, grad_fn=<SqueezeBackward0>)
# tensor([[0.4076]], grad_fn=<AddmmBackward>)
# tensor(0.6005, grad_fn=<SqueezeBackward0>)
# tensor([[1.2331]], grad_fn=<AddmmBackward>)
# tensor(0.7744, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9729]], grad_fn=<AddmmBackward>)
# tensor(0.2743, grad_fn=<SqueezeBackward0>)
# tensor([[0.8260]], grad_fn=<AddmmBackward>)
# tensor(0.6955, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0700]], grad_fn=<AddmmBackward>)
# tensor(0.4825, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0095]], grad_fn=<AddmmBackward>)
# tensor(0.4976, grad_fn=<SqueezeBackward0>)
# tensor([[1.0715]], grad_fn=<AddmmBackward>)
# tensor(0.7449, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3403]], grad_fn=<AddmmBackward>)
# tensor(0.4157, grad_fn=<SqueezeBackward0>)
# tensor([[0.0306]], grad_fn=<AddmmBackward>)
# tensor(0.5076, grad_fn=<SqueezeBackward0>)
# tensor([[0.2226]], grad_fn=<AddmmBackward>)
# tensor(0.5554, grad_fn=<SqueezeBackward0>)
# tensor([[0.2277]], grad_fn=<AddmmBackward>)
# tensor(0.5567, grad_fn=<SqueezeBackward0>)
# tensor([[0.3961]], grad_fn=<AddmmBackward>)
# ...
# tensor(0.5438, grad_fn=<SqueezeBackward0>)
# tensor([[0.4454]], grad_fn=<AddmmBackward>)
# tensor(0.6095, grad_fn=<SqueezeBackward0>)
# tensor([[0.4033]], grad_fn=<AddmmBackward>)
# tensor(0.5995, grad_fn=<SqueezeBackward0>)
# tensor([[0.2351]], grad_fn=<AddmmBackward>)
# tensor(0.5585, grad_fn=<SqueezeBackward0>)
# tensor([[0.6973]], grad_fn=<AddmmBackward>)
# tensor(0.6676, grad_fn=<SqueezeBackward0>)
# tensor([[0.8004]], grad_fn=<AddmmBackward>)
# tensor(0.6901, grad_fn=<SqueezeBackward0>)
# tensor([[0.1992]], grad_fn=<AddmmBackward>)
# tensor(0.5496, grad_fn=<SqueezeBackward0>)
# tensor([[0.0354]], grad_fn=<AddmmBackward>)
# tensor(0.5088, grad_fn=<SqueezeBackward0>)
# tensor([[0.7183]], grad_fn=<AddmmBackward>)
# tensor(0.6722, grad_fn=<SqueezeBackward0>)
# tensor([[0.5874]], grad_fn=<AddmmBackward>)
# tensor(0.6428, grad_fn=<SqueezeBackward0>)
# tensor([[0.6052]], grad_fn=<AddmmBackward>)
# tensor(0.6469, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0800]], grad_fn=<AddmmBackward>)
# tensor(0.4800, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2777]], grad_fn=<AddmmBackward>)
# tensor(0.4310, grad_fn=<SqueezeBackward0>)
# tensor([[1.0304]], grad_fn=<AddmmBackward>)
# tensor(0.7370, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6828]], grad_fn=<AddmmBackward>)
# tensor(0.3356, grad_fn=<SqueezeBackward0>)
# tensor([[0.7934]], grad_fn=<AddmmBackward>)
# tensor(0.6886, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0274]], grad_fn=<AddmmBackward>)
# tensor(0.2636, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1982]], grad_fn=<AddmmBackward>)
# tensor(0.4506, grad_fn=<SqueezeBackward0>)
# tensor([[-1.6122]], grad_fn=<AddmmBackward>)
# tensor(0.1663, grad_fn=<SqueezeBackward0>)
# tensor([[0.1425]], grad_fn=<AddmmBackward>)
# tensor(0.5356, grad_fn=<SqueezeBackward0>)
# tensor([[0.6862]], grad_fn=<AddmmBackward>)
# tensor(0.6651, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3926]], grad_fn=<AddmmBackward>)
# tensor(0.4031, grad_fn=<SqueezeBackward0>)
# tensor([[0.4114]], grad_fn=<AddmmBackward>)
# tensor(0.6014, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2412]], grad_fn=<AddmmBackward>)
# tensor(0.4400, grad_fn=<SqueezeBackward0>)
# tensor([[1.0691]], grad_fn=<AddmmBackward>)
# tensor(0.7444, grad_fn=<SqueezeBackward0>)
# tensor([[0.6446]], grad_fn=<AddmmBackward>)
# tensor(0.6558, grad_fn=<SqueezeBackward0>)
# tensor([[1.1766]], grad_fn=<AddmmBackward>)
# tensor(0.7643, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4582]], grad_fn=<AddmmBackward>)
# tensor(0.3874, grad_fn=<SqueezeBackward0>)
# tensor([[0.0871]], grad_fn=<AddmmBackward>)
# tensor(0.5218, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1460]], grad_fn=<AddmmBackward>)
# tensor(0.4636, grad_fn=<SqueezeBackward0>)
# tensor([[0.5105]], grad_fn=<AddmmBackward>)
# tensor(0.6249, grad_fn=<SqueezeBackward0>)
# tensor([[0.1036]], grad_fn=<AddmmBackward>)
# tensor(0.5259, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2240]], grad_fn=<AddmmBackward>)
# tensor(0.4442, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2819]], grad_fn=<AddmmBackward>)
# tensor(0.4300, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9974]], grad_fn=<AddmmBackward>)
# tensor(0.2695, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3999]], grad_fn=<AddmmBackward>)
# tensor(0.4013, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0448]], grad_fn=<AddmmBackward>)
# tensor(0.2602, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2974]], grad_fn=<AddmmBackward>)
# tensor(0.4262, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1550]], grad_fn=<AddmmBackward>)
# tensor(0.4613, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3948]], grad_fn=<AddmmBackward>)
# tensor(0.4026, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5657]], grad_fn=<AddmmBackward>)
# tensor(0.3622, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2631]], grad_fn=<AddmmBackward>)
# tensor(0.4346, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2539]], grad_fn=<AddmmBackward>)
# tensor(0.4369, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0018]], grad_fn=<AddmmBackward>)
# tensor(0.4995, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3754]], grad_fn=<AddmmBackward>)
# tensor(0.4072, grad_fn=<SqueezeBackward0>)
# tensor([[0.4716]], grad_fn=<AddmmBackward>)
# tensor(0.6158, grad_fn=<SqueezeBackward0>)
# tensor([[0.2244]], grad_fn=<AddmmBackward>)
# tensor(0.5559, grad_fn=<SqueezeBackward0>)
# tensor([[1.2691]], grad_fn=<AddmmBackward>)
# tensor(0.7806, grad_fn=<SqueezeBackward0>)
# tensor([[0.4970]], grad_fn=<AddmmBackward>)
# tensor(0.6217, grad_fn=<SqueezeBackward0>)
# tensor([[0.1156]], grad_fn=<AddmmBackward>)
# tensor(0.5289, grad_fn=<SqueezeBackward0>)
# tensor([[1.0782]], grad_fn=<AddmmBackward>)
# tensor(0.7462, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4499]], grad_fn=<AddmmBackward>)
# tensor(0.3894, grad_fn=<SqueezeBackward0>)
# tensor([[0.7994]], grad_fn=<AddmmBackward>)
# tensor(0.6899, grad_fn=<SqueezeBackward0>)
# tensor([[1.2326]], grad_fn=<AddmmBackward>)
# tensor(0.7743, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2140]], grad_fn=<AddmmBackward>)
# tensor(0.4467, grad_fn=<SqueezeBackward0>)
# tensor([[0.1380]], grad_fn=<AddmmBackward>)
# tensor(0.5344, grad_fn=<SqueezeBackward0>)
# tensor([[0.3170]], grad_fn=<AddmmBackward>)
# tensor(0.5786, grad_fn=<SqueezeBackward0>)
# tensor([[0.2549]], grad_fn=<AddmmBackward>)
# tensor(0.5634, grad_fn=<SqueezeBackward0>)
# tensor([[0.0188]], grad_fn=<AddmmBackward>)
# tensor(0.5047, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5519]], grad_fn=<AddmmBackward>)
# tensor(0.3654, grad_fn=<SqueezeBackward0>)
# tensor([[0.6415]], grad_fn=<AddmmBackward>)
# tensor(0.6551, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0204]], grad_fn=<AddmmBackward>)
# tensor(0.4949, grad_fn=<SqueezeBackward0>)
# tensor([[0.4166]], grad_fn=<AddmmBackward>)
# tensor(0.6027, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7093]], grad_fn=<AddmmBackward>)
# tensor(0.3298, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1639]], grad_fn=<AddmmBackward>)
# tensor(0.4591, grad_fn=<SqueezeBackward0>)
# tensor([[0.4316]], grad_fn=<AddmmBackward>)
# tensor(0.6062, grad_fn=<SqueezeBackward0>)
# tensor([[0.6215]], grad_fn=<AddmmBackward>)
# tensor(0.6506, grad_fn=<SqueezeBackward0>)
# tensor([[0.6921]], grad_fn=<AddmmBackward>)
# tensor(0.6664, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1687]], grad_fn=<AddmmBackward>)
# tensor(0.4579, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3662]], grad_fn=<AddmmBackward>)
# tensor(0.4095, grad_fn=<SqueezeBackward0>)
# tensor([[0.4575]], grad_fn=<AddmmBackward>)
# tensor(0.6124, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7970]], grad_fn=<AddmmBackward>)
# tensor(0.3107, grad_fn=<SqueezeBackward0>)
# tensor([[0.8212]], grad_fn=<AddmmBackward>)
# tensor(0.6945, grad_fn=<SqueezeBackward0>)
# tensor([[0.9287]], grad_fn=<AddmmBackward>)
# tensor(0.7168, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7407]], grad_fn=<AddmmBackward>)
# tensor(0.3229, grad_fn=<SqueezeBackward0>)
# tensor([[0.0864]], grad_fn=<AddmmBackward>)
# tensor(0.5216, grad_fn=<SqueezeBackward0>)
# tensor([[0.0911]], grad_fn=<AddmmBackward>)
# tensor(0.5228, grad_fn=<SqueezeBackward0>)
# tensor([[-1.4490]], grad_fn=<AddmmBackward>)
# tensor(0.1902, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0883]], grad_fn=<AddmmBackward>)
# tensor(0.4779, grad_fn=<SqueezeBackward0>)
# tensor([[0.7458]], grad_fn=<AddmmBackward>)
# tensor(0.6783, grad_fn=<SqueezeBackward0>)
# tensor([[0.5955]], grad_fn=<AddmmBackward>)
# tensor(0.6446, grad_fn=<SqueezeBackward0>)
# tensor([[0.3396]], grad_fn=<AddmmBackward>)
# tensor(0.5841, grad_fn=<SqueezeBackward0>)
# tensor([[0.4977]], grad_fn=<AddmmBackward>)
# tensor(0.6219, grad_fn=<SqueezeBackward0>)
# tensor([[0.6233]], grad_fn=<AddmmBackward>)
# tensor(0.6510, grad_fn=<SqueezeBackward0>)
# tensor([[0.8358]], grad_fn=<AddmmBackward>)
# tensor(0.6976, grad_fn=<SqueezeBackward0>)
# tensor([[1.2300]], grad_fn=<AddmmBackward>)
# tensor(0.7738, grad_fn=<SqueezeBackward0>)
# tensor([[0.8435]], grad_fn=<AddmmBackward>)
# tensor(0.6992, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4686]], grad_fn=<AddmmBackward>)
# tensor(0.3849, grad_fn=<SqueezeBackward0>)
# tensor([[-1.4389]], grad_fn=<AddmmBackward>)
# tensor(0.1917, grad_fn=<SqueezeBackward0>)
# tensor([[0.2506]], grad_fn=<AddmmBackward>)
# tensor(0.5623, grad_fn=<SqueezeBackward0>)
# tensor([[0.0171]], grad_fn=<AddmmBackward>)
# tensor(0.5043, grad_fn=<SqueezeBackward0>)
# tensor([[0.0312]], grad_fn=<AddmmBackward>)
# tensor(0.5078, grad_fn=<SqueezeBackward0>)
# tensor([[0.5601]], grad_fn=<AddmmBackward>)
# tensor(0.6365, grad_fn=<SqueezeBackward0>)
# tensor([[0.8236]], grad_fn=<AddmmBackward>)
# tensor(0.6950, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0080]], grad_fn=<AddmmBackward>)
# tensor(0.4980, grad_fn=<SqueezeBackward0>)
# tensor([[1.1014]], grad_fn=<AddmmBackward>)
# tensor(0.7505, grad_fn=<SqueezeBackward0>)
# tensor([[1.0528]], grad_fn=<AddmmBackward>)
# tensor(0.7413, grad_fn=<SqueezeBackward0>)
# tensor([[-1.1864]], grad_fn=<AddmmBackward>)
# tensor(0.2339, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1759]], grad_fn=<AddmmBackward>)
# tensor(0.4561, grad_fn=<SqueezeBackward0>)
# tensor([[-1.5783]], grad_fn=<AddmmBackward>)
# tensor(0.1710, grad_fn=<SqueezeBackward0>)
# tensor([[0.1769]], grad_fn=<AddmmBackward>)
# tensor(0.5441, grad_fn=<SqueezeBackward0>)
# tensor([[0.2130]], grad_fn=<AddmmBackward>)
# tensor(0.5531, grad_fn=<SqueezeBackward0>)
# tensor([[2.0793]], grad_fn=<AddmmBackward>)
# tensor(0.8889, grad_fn=<SqueezeBackward0>)
# tensor([[1.0473]], grad_fn=<AddmmBackward>)
# tensor(0.7402, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6156]], grad_fn=<AddmmBackward>)
# tensor(0.3508, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0402]], grad_fn=<AddmmBackward>)
# tensor(0.4899, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0464]], grad_fn=<AddmmBackward>)
# tensor(0.4884, grad_fn=<SqueezeBackward0>)
# tensor([[0.3772]], grad_fn=<AddmmBackward>)
# tensor(0.5932, grad_fn=<SqueezeBackward0>)
# tensor([[-0.7112]], grad_fn=<AddmmBackward>)
# tensor(0.3293, grad_fn=<SqueezeBackward0>)
# tensor([[0.1201]], grad_fn=<AddmmBackward>)
# tensor(0.5300, grad_fn=<SqueezeBackward0>)
# tensor([[0.0567]], grad_fn=<AddmmBackward>)
# tensor(0.5142, grad_fn=<SqueezeBackward0>)
# tensor([[0.1213]], grad_fn=<AddmmBackward>)
# tensor(0.5303, grad_fn=<SqueezeBackward0>)
# tensor([[0.4200]], grad_fn=<AddmmBackward>)
# tensor(0.6035, grad_fn=<SqueezeBackward0>)
# tensor([[-0.8241]], grad_fn=<AddmmBackward>)
# tensor(0.3049, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0677]], grad_fn=<AddmmBackward>)
# tensor(0.4831, grad_fn=<SqueezeBackward0>)
# tensor([[0.9788]], grad_fn=<AddmmBackward>)
# tensor(0.7269, grad_fn=<SqueezeBackward0>)
# tensor([[0.7156]], grad_fn=<AddmmBackward>)
# tensor(0.6716, grad_fn=<SqueezeBackward0>)
# tensor([[0.8736]], grad_fn=<AddmmBackward>)
# tensor(0.7055, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0401]], grad_fn=<AddmmBackward>)
# tensor(0.4900, grad_fn=<SqueezeBackward0>)
# tensor([[0.4400]], grad_fn=<AddmmBackward>)
# tensor(0.6083, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5542]], grad_fn=<AddmmBackward>)
# tensor(0.3649, grad_fn=<SqueezeBackward0>)
# tensor([[0.3197]], grad_fn=<AddmmBackward>)
# tensor(0.5793, grad_fn=<SqueezeBackward0>)
# tensor([[0.1113]], grad_fn=<AddmmBackward>)
# tensor(0.5278, grad_fn=<SqueezeBackward0>)
# tensor([[0.3843]], grad_fn=<AddmmBackward>)
# tensor(0.5949, grad_fn=<SqueezeBackward0>)
# tensor([[0.7472]], grad_fn=<AddmmBackward>)
# tensor(0.6786, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0694]], grad_fn=<AddmmBackward>)
# tensor(0.4826, grad_fn=<SqueezeBackward0>)
# tensor([[-0.9267]], grad_fn=<AddmmBackward>)
# tensor(0.2836, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0050]], grad_fn=<AddmmBackward>)
# tensor(0.4988, grad_fn=<SqueezeBackward0>)
# tensor([[1.0321]], grad_fn=<AddmmBackward>)
# tensor(0.7373, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4876]], grad_fn=<AddmmBackward>)
# tensor(0.3804, grad_fn=<SqueezeBackward0>)
# tensor([[1.5130]], grad_fn=<AddmmBackward>)
# tensor(0.8195, grad_fn=<SqueezeBackward0>)
# tensor([[0.9701]], grad_fn=<AddmmBackward>)
# tensor(0.7251, grad_fn=<SqueezeBackward0>)
# tensor([[0.2658]], grad_fn=<AddmmBackward>)
# tensor(0.5661, grad_fn=<SqueezeBackward0>)
# tensor([[-0.6011]], grad_fn=<AddmmBackward>)
# tensor(0.3541, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3462]], grad_fn=<AddmmBackward>)
# tensor(0.4143, grad_fn=<SqueezeBackward0>)
# tensor([[0.5828]], grad_fn=<AddmmBackward>)
# tensor(0.6417, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2825]], grad_fn=<AddmmBackward>)
# tensor(0.4298, grad_fn=<SqueezeBackward0>)
# tensor([[-0.5088]], grad_fn=<AddmmBackward>)
# tensor(0.3755, grad_fn=<SqueezeBackward0>)
# tensor([[-0.3429]], grad_fn=<AddmmBackward>)
# tensor(0.4151, grad_fn=<SqueezeBackward0>)
# tensor([[0.5693]], grad_fn=<AddmmBackward>)
# tensor(0.6386, grad_fn=<SqueezeBackward0>)
# tensor([[-0.0183]], grad_fn=<AddmmBackward>)
# tensor(0.4954, grad_fn=<SqueezeBackward0>)
# tensor([[0.8483]], grad_fn=<AddmmBackward>)
# tensor(0.7002, grad_fn=<SqueezeBackward0>)
# tensor([[0.3118]], grad_fn=<AddmmBackward>)
# tensor(0.5773, grad_fn=<SqueezeBackward0>)
# tensor([[0.7799]], grad_fn=<AddmmBackward>)
# tensor(0.6857, grad_fn=<SqueezeBackward0>)
# tensor([[0.1678]], grad_fn=<AddmmBackward>)
# tensor(0.5418, grad_fn=<SqueezeBackward0>)
# tensor([[-1.0324]], grad_fn=<AddmmBackward>)
# tensor(0.2626, grad_fn=<SqueezeBackward0>)
# tensor([[0.3943]], grad_fn=<AddmmBackward>)
# tensor(0.5973, grad_fn=<SqueezeBackward0>)
# tensor([[0.9494]], grad_fn=<AddmmBackward>)
# tensor(0.7210, grad_fn=<SqueezeBackward0>)
# tensor([[0.9349]], grad_fn=<AddmmBackward>)
# tensor(0.7181, grad_fn=<SqueezeBackward0>)
# tensor([[-0.4177]], grad_fn=<AddmmBackward>)
# tensor(0.3971, grad_fn=<SqueezeBackward0>)
# tensor([[0.4212]], grad_fn=<AddmmBackward>)
# tensor(0.6038, grad_fn=<SqueezeBackward0>)
# tensor([[0.7787]], grad_fn=<AddmmBackward>)
# tensor(0.6854, grad_fn=<SqueezeBackward0>)
# tensor([[0.1734]], grad_fn=<AddmmBackward>)
# tensor(0.5432, grad_fn=<SqueezeBackward0>)
# tensor([[0.6281]], grad_fn=<AddmmBackward>)
# tensor(0.6521, grad_fn=<SqueezeBackward0>)
# tensor([[-0.1757]], grad_fn=<AddmmBackward>)
# tensor(0.4562, grad_fn=<SqueezeBackward0>)
# tensor([[0.4106]], grad_fn=<AddmmBackward>)
# tensor(0.6012, grad_fn=<SqueezeBackward0>)
# tensor([[-0.2413]], grad_fn=<AddmmBackward>)
# tensor(0.4400, grad_fn=<SqueezeBackward0>)
# tensor([[0.2257]], grad_fn=<AddmmBackward>)
# tensor(0.5562, grad_fn=<SqueezeBackward0>)
# tensor([[0.7795]], grad_fn=<AddmmBackward>)
# tensor(0.6856, grad_fn=<SqueezeBackward0>)
# tensor([[0.1431]], grad_fn=<AddmmBackward>)
# tensor(0.5357, grad_fn=<SqueezeBackward0>)
# tensor([[0.1501]], grad_fn=<AddmmBackward>)
# tensor(0.5374, grad_fn=<SqueezeBackward0>)
# tensor([[0.2704]], grad_fn=<AddmmBackward>)
# tensor(0.5672, grad_fn=<SqueezeBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-15bdbc3d2d4e> in <module>
#       8         for v,u,l in zip(pair_first_elem,pair_second_elem,labels):
#       9             p = model(v, u)
# ---> 10             loss = loss_function(p,torch.Tensor([l]))
#      11             loss += loss.data
#      12         loss.backward()
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     496
#     497     def forward(self, input, target):
# --> 498         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     499
#     500
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2035         reduction_enum = _Reduction.legacy_get_enum(size_average, reduce)
#    2036     else:
# -> 2037         reduction_enum = _Reduction.get_enum(reduction)
#    2038     if target.size() != input.size():
#    2039         warnings.warn("Using a target size ({}) that is different to the input size ({}) is deprecated. "
#
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/nn/_reduction.py in get_enum(reduction)
#       6 def get_enum(reduction):
#       7     # type: (str) -> int
# ----> 8     if reduction == 'none':
#       9         ret = 0
#      10     elif reduction == 'mean':
#
# KeyboardInterrupt:

# %%
weights = model.u_embeddings(torch.Tensor([list(range(0,vocab_size))]).long())
pd.DataFrame(weights.view(-1,100).tolist(), index=list(id2word.values())[0:]).head()
# Out:
#               0         1         2         3         4         5         6   \
# said    0.179425 -0.185343 -1.183711  0.319763  0.042209  0.623948 -0.561809
# alice   1.880033  0.255972  1.193151 -0.389575  0.123183  0.672558 -1.753153
# little  0.132771 -1.839545 -0.230088  0.125555  0.727814  0.487313 -0.361747
# one     0.297157 -0.756851  0.395955 -0.707532 -1.251330  0.053592  1.581376
# would  -1.655144  0.310861  0.046035 -1.526546 -0.176150 -1.221822 -1.449021
#
#               7         8         9   ...        90        91        92  \
# said   -1.943918 -1.053007  0.553827  ... -0.175016 -1.045109  0.439342
# alice  -1.473195 -0.291848  0.986159  ... -2.370818 -1.635316  0.767438
# little -2.471758 -0.449868  0.372703  ...  0.815969 -0.256952 -0.088617
# one     0.502552  1.432852 -0.320592  ...  0.832119  2.580865  0.488905
# would   0.452992 -2.528788 -0.093987  ... -1.774470  0.795702 -0.244212
#
#               93        94        95        96        97        98        99
# said   -0.133949  0.057302  1.868297 -1.170673 -0.017717 -0.382825 -1.382537
# alice  -0.700730 -0.025119  0.102825 -0.139166 -1.624705 -0.008383  0.323928
# little -1.695642 -1.624261  0.437490 -1.392092 -0.698966  0.790800 -0.781900
# one     0.745850  0.020350 -0.451972  0.436855 -0.264077 -1.419990  0.907573
# would  -1.088123  0.166646 -1.195401 -1.106316  0.192364  0.565457  0.744719
#
# [5 rows x 100 columns]

# %%
from sklearn.metrics.pairwise import euclidean_distances

weights = weights.view(-1,100)
distance_matrix = euclidean_distances(weights.detach().numpy())

similar_words = {search_term: [id2word[idx] for idx in distance_matrix[word2id[search_term]-1].argsort()[1:6]+1] 
                   for search_term in ['little', 'small', 'would', 'child','girl']}

similar_words
# Out:
# {'little': ['tied', 'dish', 'burn', 'sixpence', 'oop'],
#  'small': ['eh', 'shoulders', 'straightened', 'came', 'turtle'],
#  'would': ['jaws', 'egg', 'stuff', 'send', 'tomorrow'],
#  'child': ['hat', 'cattle', 'sulky', 'quietly', 'camomile'],
#  'girl': ['catch', 'came', 'teacup', 'puss', 'smaller']}
